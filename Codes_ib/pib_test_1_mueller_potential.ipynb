# %%
import matplotlib.pyplot as plt
import torch
from torch import nn, optim, autograd
from torch.nn import functional as F

import numpy as np
import scipy.spatial
import math
import os
import pyemma as pe
USE_GPU = torch.cuda.is_available()

# %%
Dx = 2
N =10000
kBT = 20
repeat_times = 100
os.makedirs('./Data', exist_ok=True)

# %%
aa = [-1, -1, -6.5, 0.7]
bb = [0, 0, 11, 0.6]
cc = [-10, -10, -6.5, 0.7]
AA = [-200, -100, -170, 15]
XX = [1, 0, -0.5, -1]
YY = [0, 0.5, 1.5, 1]
sigma = 0.05

# %%
def get_V(px):
    px = np.array(px)
    ee = 0
    if USE_GPU:
        px = px.cuda()
        ee = ee.cuda()
    if np.size(px.shape) == 2:
        for j in range(4):
            ee = ee + AA[j] * np.exp(aa[j] * (px[:, 0] - XX[j]) ** 2 +
                                              bb[j] * (px[:, 0] - XX[j]) * (px[:, 1] - YY[j]) +
                                              cc[j] * (px[:, 1] - YY[j]) ** 2)
        ee += 9 * np.sin(2 * 5 * np.pi * px[:, 0]) * np.sin(2 * 5 * np.pi * px[:, 1])
        for i in range(2, Dx):
            ee += px[:, i] ** 2 / 2 / sigma ** 2
    else:
        for j in range(4):
            ee = ee + AA[j] * np.exp(aa[j] * (px[0] - XX[j]) ** 2 +
                                              bb[j] * (px[0] - XX[j]) * (px[1] - YY[j]) +
                                              cc[j] * (px[1] - YY[j]) ** 2)
        ee += 9 * np.sin(2 * 5 * np.pi * px[0]) * np.sin(2 * 5 * np.pi * px[1])
        for i in range(2, Dx):
            ee += px[i] ** 2 / 2 / sigma ** 2
    return ee

# %%
def get_grad(px):
    px = np.array(px)
    gg = np.zeros(shape=(Dx,), dtype=np.float64)
    if USE_GPU:
        px = px.cuda()
        gg = gg.cuda()
    for j in range(4):
        ee = AA[j] * np.exp(aa[j] * (px[0] - XX[j]) ** 2 +
                                     bb[j] * (px[0] - XX[j]) * (px[1] - YY[j]) +
                                     cc[j] * (px[1] - YY[j]) ** 2)
        gg[0] = gg[0] + (2 * aa[j] * (px[0] - XX[j]) +
                             bb[j] * (px[1] - YY[j])) * ee
        gg[1] = gg[1] + (bb[j] * (px[0] - XX[j]) +
                             2 * cc[j] * (px[1] - YY[j])) * ee
    gg[0] += 9 * 2 * 5 * np.pi * np.cos(2 * 5 * np.pi * px[0]) * np.sin(2 * 5 * np.pi * px[1])
    gg[1] += 9 * 2 * 5 * np.pi * np.sin(2 * 5 * np.pi * px[0]) * np.cos(2 * 5 * np.pi * px[1])
    for i in range(2, Dx):
        gg[i] = px[i] / sigma ** 2
    return gg

# %%
def sim_data(px_init, kBT, dt, D_size, firstsave=1000, t_sep=100):
    D = []
    px = px_init
    id_ = 0
    i = 0
    if USE_GPU:
        D = D.cuda()
        px = px.cuda()
    while True:
        px = px - dt * get_grad(px) + np.sqrt(2 * kBT * dt) * np.random.normal(size=(Dx,))
        if i >= firstsave and i % t_sep == 0 and 1 >= px[0] >= -1.5 \
                and 2 >= px[1] >= -0.5:
            D.append(px)
            id_ += 1
            if id_ >= D_size:
                break
        i += 1
    data = np.zeros((D_size, 1 + Dx))
    data[:, 1:] = np.array(D)
    data[:, 0] = get_V(D)
#     print('generating data finished!')
    return data

# %%
data_ori = []
for i in range(repeat_times):
    x1 = np.random.uniform(low = -1.0, high = 1.0)
    x2 = np.random.uniform(low = -1.0, high = 1.0)
    px_init = np.zeros((Dx,))
    px_init[0] = x1
    px_init[1] = x2
    data_ori_t = sim_data(px_init = px_init, kBT = kBT, dt = 1e-5, D_size = N)
    data_ori.extend(data_ori_t)
print(np.shape(data_ori))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-d441e04574d2> in <module>
#       6     px_init[0] = x1
#       7     px_init[1] = x2
# ----> 8     data_ori_t = sim_data(px_init = px_init, kBT = kBT, dt = 1e-5, D_size = N)
#       9     data_ori.extend(data_ori_t)
#      10 print(np.shape(data_ori))
#
# <ipython-input-54-4d34e54bc5b7> in sim_data(px_init, kBT, dt, D_size, firstsave, t_sep)
#       8         px = px.cuda()
#       9     while True:
# ---> 10         px = px - dt * get_grad(px) + np.sqrt(2 * kBT * dt) * np.random.normal(size=(Dx,))
#      11         if i >= firstsave and i % t_sep == 0 and 1 >= px[0] >= -1.5 \
#      12                 and 2 >= px[1] >= -0.5:
#
# <ipython-input-53-256bd5d5c8d5> in get_grad(px)
#      12                              bb[j] * (px[1] - YY[j])) * ee
#      13         gg[1] = gg[1] + (bb[j] * (px[0] - XX[j]) +
# ---> 14                              2 * cc[j] * (px[1] - YY[j])) * ee
#      15     gg[0] += 9 * 2 * 5 * np.pi * np.cos(2 * 5 * np.pi * px[0]) * np.sin(2 * 5 * np.pi * px[1])
#      16     gg[1] += 9 * 2 * 5 * np.pi * np.sin(2 * 5 * np.pi * px[0]) * np.cos(2 * 5 * np.pi * px[1])
#
# KeyboardInterrupt:

# %%
np.savetxt('Data/data_'+str(N)+'_'+str(kBT)+'_'+str(repeat_times), data_ori)

# %%
data_ori = np.loadtxt('Data/data_'+str(N)+'_'+str(kBT)+'_'+str(repeat_times)).reshape(-1,Dx+1)

# %%
print(np.shape(data_ori))
# Out:
# (1000000, 3)

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.scatter(data_ori[:, 1], data_ori[:, 2], marker='o',lw = 0.75,c=data_ori[:,0], cmap = plt.cm.get_cmap('nipy_spectral', 20))
ax.set_title('V(x)')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
# Out:
# Text(0, 0.5, 'x2')

# %%
pe.plots.plot_free_energy(data_ori[:,1],data_ori[:,2])
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fefe1231d30>)

# %%
X0 = torch.from_numpy(data_ori[:20000, 1:]).float()
print(X0.size())

X1 = torch.from_numpy(data_ori[100:20100, 1:]).float()
print(X1.size())
# Out:
# torch.Size([20000, 2])
# torch.Size([20000, 2])

# %%
pe.plots.plot_free_energy(X0[:,0].numpy(),X0[:,1].numpy())
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fefdc96b518>)

# %%
train_batch_size = 128

train_loader = torch.utils.data.DataLoader(
    torch.cat([X0, X1], 1), batch_size = train_batch_size, shuffle = True)

# %%
Dr = 1


R_net = nn.Sequential(
    nn.Linear(Dx, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, Dr)
    )

T_net = nn.Sequential(
    nn.Linear(Dx + Dr, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 1)
    )

# %%
lr = 1e-5
optimizer = optim.Adam(list(R_net.parameters()) + list(T_net.parameters()), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=25, gamma=0.1)

n_epochs = 40
train_data_size = len(train_loader.dataset)
for epoch in range(1, n_epochs + 1):
    train_loss = 0
    for batch_idx, data in enumerate(train_loader):

        actual_size = len(data)
        data = data
        data_X0 = data[:, :Dx]
        data_X1 = data[:, Dx:2*Dx]
        #rand_ind = np.random.choice(train_data_size, actual_size, replace=False)
        #data_iX1 = train_loader.dataset[rand_ind, Dx:2*Dx].to(device)
        data_iX1 = data_X1[torch.randperm(actual_size)]
        R0 = R_net(data_X0)
        T_J = T_net(torch.cat([R0, data_X1], 1))
        T_I = T_net(torch.cat([R0, data_iX1], 1))
        loss = -T_J.mean() + torch.logsumexp(T_I, 0)[0]

        train_loss += loss.item() * len(data)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    train_loss /= len(train_loader.dataset)
    
    if epoch % 1 == 0:
        print('Train Epoch: {} ===> Train set loss: {:.4f}'.format(epoch, train_loss))
    
    scheduler.step()
# Out:
# Train Epoch: 1 ===> Train set loss: 4.8498
# Train Epoch: 2 ===> Train set loss: 4.8496
# Train Epoch: 3 ===> Train set loss: 4.8491
# Train Epoch: 4 ===> Train set loss: 4.8474
# Train Epoch: 5 ===> Train set loss: 4.8434
# Train Epoch: 6 ===> Train set loss: 4.8351
# Train Epoch: 7 ===> Train set loss: 4.8214
# Train Epoch: 8 ===> Train set loss: 4.8017
# Train Epoch: 9 ===> Train set loss: 4.7835
# Train Epoch: 10 ===> Train set loss: 4.7672
# Train Epoch: 11 ===> Train set loss: 4.7507
# Train Epoch: 12 ===> Train set loss: 4.7361
# Train Epoch: 13 ===> Train set loss: 4.7288
# Train Epoch: 14 ===> Train set loss: 4.7248
# Train Epoch: 15 ===> Train set loss: 4.7140
# Train Epoch: 16 ===> Train set loss: 4.7227
# Train Epoch: 17 ===> Train set loss: 4.7104
# Train Epoch: 18 ===> Train set loss: 4.7197
# Train Epoch: 19 ===> Train set loss: 4.7140
# Train Epoch: 20 ===> Train set loss: 4.7160
# Train Epoch: 21 ===> Train set loss: 4.7102
# Train Epoch: 22 ===> Train set loss: 4.7127
# Train Epoch: 23 ===> Train set loss: 4.7111
# Train Epoch: 24 ===> Train set loss: 4.7098
# Train Epoch: 25 ===> Train set loss: 4.7063
# Train Epoch: 26 ===> Train set loss: 4.7121
# Train Epoch: 27 ===> Train set loss: 4.7069
# Train Epoch: 28 ===> Train set loss: 4.7127
# Train Epoch: 29 ===> Train set loss: 4.7079
# Train Epoch: 30 ===> Train set loss: 4.7100
# Train Epoch: 31 ===> Train set loss: 4.7078
# Train Epoch: 32 ===> Train set loss: 4.7091
# Train Epoch: 33 ===> Train set loss: 4.7048
# Train Epoch: 34 ===> Train set loss: 4.7089
# Train Epoch: 35 ===> Train set loss: 4.7105
# Train Epoch: 36 ===> Train set loss: 4.7104
# Train Epoch: 37 ===> Train set loss: 4.7135
# Train Epoch: 38 ===> Train set loss: 4.7014
# Train Epoch: 39 ===> Train set loss: 4.7147
# Train Epoch: 40 ===> Train set loss: 4.7159

# %%
R = R_net(X0).detach().numpy()
print(np.shape(R))
x1 = X0[:,0].numpy()
x2 = X0[:,1].numpy()
print(np.shape(x1))
print(np.shape(x2))
# Out:
# (20000, 1)
# (20000,)
# (20000,)

# %%
pe.plots.plot_free_energy(x1,x2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fefe3d81978>)

# %%
# R = R_net(X0.to(device))
# plt.plot(X0_bar.cpu().detach().numpy()[:, 0], R.cpu().detach().numpy()[:, 0], 'o')

fig, ax = plt.subplots(figsize=(8, 5))
Rd1 = ax.scatter(x1.reshape(-1,1), x2.reshape(-1,1), marker='o',lw = 0.5, c = R, cmap = plt.cm.get_cmap('nipy_spectral', 40))
ax.set_title('R(X)')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
fig.colorbar(Rd1)
