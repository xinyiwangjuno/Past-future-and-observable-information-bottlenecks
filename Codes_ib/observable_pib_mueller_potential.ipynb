# %%
import matplotlib.pyplot as plt
import torch
from torch import nn, optim, autograd
from torch.nn import functional as F

import numpy as np
import scipy.spatial
import math
import os
import pyemma as pe
from mpl_toolkits import mplot3d

# %%
Dx = 3
N =10000
kBT = 20
repeat_times = 100

aa = [-1, -1, -6.5, 0.7]
bb = [0, 0, 11, 0.6]
cc = [-10, -10, -6.5, 0.7]
AA = [-200, -100, -170, 15]
XX = [1, 0, -0.5, -1]
YY = [0, 0.5, 1.5, 1]
sigma = 0.05
os.makedirs('./Data', exist_ok=True)
USE_GPU = torch.cuda.is_available()

# %%
def get_V(px):
    px = np.array(px)
    ee = 0
    if np.size(px.shape) == 2:
        for j in range(4):
            ee = ee + AA[j] * np.exp(aa[j] * (px[:, 0] - XX[j]) ** 2 +
                                              bb[j] * (px[:, 0] - XX[j]) * (px[:, 1] - YY[j]) +
                                              cc[j] * (px[:, 1] - YY[j]) ** 2)
        ee += 9 * np.sin(2 * 5 * np.pi * px[:, 0]) * np.sin(2 * 5 * np.pi * px[:, 1])
        for i in range(2, Dx):
            ee += px[:, i] ** 2 / 2 / sigma ** 2
    else:
        for j in range(4):
            ee = ee + AA[j] * np.exp(aa[j] * (px[0] - XX[j]) ** 2 +
                                              bb[j] * (px[0] - XX[j]) * (px[1] - YY[j]) +
                                              cc[j] * (px[1] - YY[j]) ** 2)
        ee += 9 * np.sin(2 * 5 * np.pi * px[0]) * np.sin(2 * 5 * np.pi * px[1])
        for i in range(2, Dx):
            ee += px[i] ** 2 / 2 / sigma ** 2
    return ee

# %%
def get_grad(px):
    px = np.array(px)
    gg = np.zeros(shape=(Dx,), dtype=np.float64)
    for j in range(4):
        ee = AA[j] * np.exp(aa[j] * (px[0] - XX[j]) ** 2 +
                                     bb[j] * (px[0] - XX[j]) * (px[1] - YY[j]) +
                                     cc[j] * (px[1] - YY[j]) ** 2)
        gg[0] = gg[0] + (2 * aa[j] * (px[0] - XX[j]) +
                             bb[j] * (px[1] - YY[j])) * ee
        gg[1] = gg[1] + (bb[j] * (px[0] - XX[j]) +
                             2 * cc[j] * (px[1] - YY[j])) * ee
    gg[0] += 9 * 2 * 5 * np.pi * np.cos(2 * 5 * np.pi * px[0]) * np.sin(2 * 5 * np.pi * px[1])
    gg[1] += 9 * 2 * 5 * np.pi * np.sin(2 * 5 * np.pi * px[0]) * np.cos(2 * 5 * np.pi * px[1])
    for i in range(2, Dx):
        gg[i] = px[i] / sigma ** 2
    return gg

# %%
def sim_data(kBT, dt, D_size, firstsave=1000, t_sep=100):
    D = []
    px = np.zeros((Dx,))
    id_ = 0
    i = 0
    while True:
        px = px - dt * get_grad(px) + np.sqrt(2 * kBT * dt) * np.random.normal(size=(Dx,))
        if i >= firstsave and i % t_sep == 0 and 1 >= px[0] >= -1.5 \
                and 2 >= px[1] >= -0.5:
            D.append(px)
            id_ += 1
            if id_ >= D_size:
                break
        i += 1
    data = np.zeros((D_size, 1 + Dx))
    data[:, 1:] = np.array(D)
    data[:, 0] = get_V(D)
    print('generating data finished!')
    return data

# %%
data_ori = []
for i in range(repeat_times):
    data_ori_t = sim_data(kBT = kBT, dt = 1e-5, D_size = N)
    data_ori.extend(data_ori_t)
print(np.shape(data_ori))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-397f02cbe53a> in <module>
#       1 data_ori = []
#       2 for i in range(repeat_times):
# ----> 3     data_ori_t = sim_data(kBT = kBT, dt = 1e-5, D_size = N)
#       4     data_ori.extend(data_ori_t)
#       5 print(np.shape(data_ori))
#
# <ipython-input-69-06d6b7c04f81> in sim_data(kBT, dt, D_size, firstsave, t_sep)
#       5     i = 0
#       6     while True:
# ----> 7         px = px - dt * get_grad(px) + np.sqrt(2 * kBT * dt) * np.random.normal(size=(Dx,))
#       8         if i >= firstsave and i % t_sep == 0 and 1 >= px[0] >= -1.5 \
#       9                 and 2 >= px[1] >= -0.5:
#
# <ipython-input-68-a003eea1833c> in get_grad(px)
#       5         ee = AA[j] * np.exp(aa[j] * (px[0] - XX[j]) ** 2 +
#       6                                      bb[j] * (px[0] - XX[j]) * (px[1] - YY[j]) +
# ----> 7                                      cc[j] * (px[1] - YY[j]) ** 2)
#       8         gg[0] = gg[0] + (2 * aa[j] * (px[0] - XX[j]) +
#       9                              bb[j] * (px[1] - YY[j])) * ee
#
# KeyboardInterrupt:

# %%
np.savetxt('Data/data_'+str(N)+'_'+str(kBT)+'_'+str(repeat_times),data_ori)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-42d79cd47f68> in <module>
# ----> 1 np.savetxt('Data/data_'+str(N)+'_'+str(kBT)+'_'+str(repeat_times),data_ori)
#
# NameError: name 'np' is not defined

# %%
data_ori1 = np.loadtxt('Data/data_'+str(N)+'_'+str(kBT)+'_'+str(repeat_times)).reshape(-1,3)

# %%
print(np.shape(data_ori1))
# Out:
# (1000000, 3)

# %%
data_ori2 = 0.5*np.random.normal(loc = 1.0, scale = 1.0, size = (np.shape(data_ori1)[0],1) ) + 0.5*np.random.normal(loc = 3.0, scale = 1.0, size = (np.shape(data_ori1)[0],1) )

# %%
data_ori = np.concatenate((data_ori1, data_ori2), axis = 1)

# %%
print(np.shape(data_ori))
# Out:
# (1000000, 4)

# %%
fig, ax = plt.subplots(figsize=(8, 5))
pic1 = ax.scatter(data_ori[:, 1], data_ori[:, 2], marker='o',lw = 0.75,c=data_ori[:,0], cmap = plt.cm.get_cmap('nipy_spectral', 20))
ax.set_title('V(x)')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
fig.colorbar(pic1)

# %%
pe.plots.plot_free_energy(data_ori[:,1],data_ori[:,2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9f58376aa0a9> in <module>
# ----> 1 pe.plots.plot_free_energy(data_ori[:,1],data_ori[:,2])
#
# NameError: name 'data_ori' is not defined

# %%
X0 = torch.from_numpy(data_ori[:20000, 1:]).float()
print(X0.size())

X1 = torch.from_numpy(data_ori[100:20100, 1:]).float()
Dy = 2
Y0 = X0[:,:-1].reshape(-1,Dy)
Y1 = X1[:,:-1].reshape(-1,Dy)
print(Y0.size())
# Out:
# torch.Size([20000, 3])
# torch.Size([20000, 2])

# %%
train_batch_size = 128

train_loader = torch.utils.data.DataLoader(
    torch.cat([X0, X1, Y1], 1), batch_size = train_batch_size, shuffle = True)

# %%
Dr = 2


R_net = nn.Sequential(
    nn.Linear(Dx, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, Dr)
    )

T_net = nn.Sequential(
    nn.Linear(2*Dr + Dy, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 1)
    )

Tx_net = nn.Sequential(
    nn.Linear(Dx + Dr + Dy, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 64),
    nn.ReLU(),
    nn.Linear(64, 1)
    )

# %%
def learn_max(data_X0,data_X1,data_iX1,data_Y1, data_iY1, R_net, T_net , Tx_net, optimizer_max):


    if USE_GPU:
        data_X0 = data_X0.cuda()
        data_X1 = data_X1.cuda()
        data_iX1 = data_iX1.cuda()
        data_Y1 = data_Y1.cuda()
        data_iY1 = data_iY1.cuda()
 
     
    R0 = R_net(data_X0)
    R1 = R_net(data_X1)
    iR1 = R_net(data_iX1)
        
    Tx_J = Tx_net(torch.cat([data_X0, R1, data_Y1], 1))
    Tx_I = Tx_net(torch.cat([data_X0, iR1, data_iY1], 1))
    T_J = T_net(torch.cat([R0, R1, data_Y1], 1))
    T_I = T_net(torch.cat([R0, iR1, data_iY1], 1))
    
    loss = 0.
    T_loss = -T_J.mean() + torch.logsumexp(T_I, 0) + Tx_J.mean() - torch.logsumexp(Tx_I, 0) 
    loss += T_loss

     
    optimizer_max.zero_grad()
    loss.backward()
    optimizer_max.step()



    return -T_loss.item()

# %%
def learn_min(data_X0,data_X1,data_iX1,data_Y1, data_iY1, R_net, T_net , Tx_net, optimizer_min):


    if USE_GPU:
        data_X0 = data_X0.cuda()
        data_X1 = data_X1.cuda()
        data_iX1 = data_iX1.cuda()
        data_Y1 = data_Y1.cuda()
        data_iY1 = data_iY1.cuda()
 
     
    R0 = R_net(data_X0)
    R1 = R_net(data_X1)
    iR1 = R_net(data_iX1)
        
    Tx_J = Tx_net(torch.cat([data_X0, R1, data_Y1], 1))
    Tx_I = Tx_net(torch.cat([data_X0, iR1, data_iY1], 1))
    
    loss = 0.
    Tx_loss = -Tx_J.mean() + torch.logsumexp(Tx_I, 0)
    loss += Tx_loss

     
    optimizer_min.zero_grad()
    loss.backward()
    optimizer_min.step()

# %%
lr = 1e-5
optimizer_max = optim.Adam(list(R_net.parameters()) + list(T_net.parameters()), lr=lr)
scheduler_max = torch.optim.lr_scheduler.StepLR(optimizer_max, step_size=25, gamma=0.1)

optimizer_min = optim.Adam(list(Tx_net.parameters()), lr=lr)
scheduler_min = torch.optim.lr_scheduler.StepLR(optimizer_min, step_size=25, gamma=0.1)

n_epochs = 400
train_data_size = len(train_loader.dataset)
for epoch in range(1, n_epochs + 1):
    train_loss = 0
    for batch_idx, data in enumerate(train_loader):

        actual_size = len(data)
        data = data
        data_X0 = data[:, :Dx]
        data_X1 = data[:, Dx:2*Dx]
        data_Y1 = data[:, 2*Dx:]

        
        #rand_ind = np.random.choice(train_data_size, actual_size, replace=False)
        #data_iX1 = train_loader.dataset[rand_ind, Dx:2*Dx].to(device)
        data_iX1 = data_X1[torch.randperm(actual_size)]
        data_iY1 = data_Y1[torch.randperm(actual_size)]
        
        learn_min(data_X0, data_X1, data_iX1, data_Y1, data_iY1, R_net, T_net , Tx_net, optimizer_min)
        T_loss = learn_max(data_X0, data_X1, data_iX1, data_Y1, data_iY1, R_net, T_net , Tx_net, optimizer_max)
        
        

        train_loss += T_loss * len(data)
        


    train_loss /= len(train_loader.dataset)
    
    if epoch % 1 == 0:
        print('Train Epoch: {} ===> Train set loss: {:.4f}'.format(epoch, train_loss))
        
    scheduler_min.step()
    scheduler_max.step()
# Out:
# Train Epoch: 1 ===> Train set loss: -0.0004
# Train Epoch: 2 ===> Train set loss: -0.0015
# Train Epoch: 3 ===> Train set loss: -0.0022
# Train Epoch: 4 ===> Train set loss: -0.0024
# Train Epoch: 5 ===> Train set loss: -0.0010
# Train Epoch: 6 ===> Train set loss: 0.0045
# Train Epoch: 7 ===> Train set loss: 0.0172
# Train Epoch: 8 ===> Train set loss: 0.0350
# Train Epoch: 9 ===> Train set loss: 0.0600
# Train Epoch: 10 ===> Train set loss: 0.0883
# Train Epoch: 11 ===> Train set loss: 0.1171
# Train Epoch: 12 ===> Train set loss: 0.1419
# Train Epoch: 13 ===> Train set loss: 0.1677
# Train Epoch: 14 ===> Train set loss: 0.1932
# Train Epoch: 15 ===> Train set loss: 0.2155
# Train Epoch: 16 ===> Train set loss: 0.2225
# Train Epoch: 17 ===> Train set loss: 0.2404
# Train Epoch: 18 ===> Train set loss: 0.2459
# Train Epoch: 19 ===> Train set loss: 0.2355
# Train Epoch: 20 ===> Train set loss: 0.2360
# Train Epoch: 21 ===> Train set loss: 0.2261
# Train Epoch: 22 ===> Train set loss: 0.2291
# Train Epoch: 23 ===> Train set loss: 0.2235
# Train Epoch: 24 ===> Train set loss: 0.2115
# Train Epoch: 25 ===> Train set loss: 0.2001
# Train Epoch: 26 ===> Train set loss: 0.2044
# Train Epoch: 27 ===> Train set loss: 0.2006
# Train Epoch: 28 ===> Train set loss: 0.1939
# Train Epoch: 29 ===> Train set loss: 0.1967
# Train Epoch: 30 ===> Train set loss: 0.1939
# Train Epoch: 31 ===> Train set loss: 0.2015
# Train Epoch: 32 ===> Train set loss: 0.2103
# Train Epoch: 33 ===> Train set loss: 0.2053
# Train Epoch: 34 ===> Train set loss: 0.2003
# Train Epoch: 35 ===> Train set loss: 0.2006
# Train Epoch: 36 ===> Train set loss: 0.2050
# Train Epoch: 37 ===> Train set loss: 0.2004
# Train Epoch: 38 ===> Train set loss: 0.2104
# Train Epoch: 39 ===> Train set loss: 0.1999
# Train Epoch: 40 ===> Train set loss: 0.2019
# Train Epoch: 41 ===> Train set loss: 0.2007
# Train Epoch: 42 ===> Train set loss: 0.1914
# Train Epoch: 43 ===> Train set loss: 0.2020
# Train Epoch: 44 ===> Train set loss: 0.2021
# Train Epoch: 45 ===> Train set loss: 0.2052
# Train Epoch: 46 ===> Train set loss: 0.1989
# Train Epoch: 47 ===> Train set loss: 0.2149
# Train Epoch: 48 ===> Train set loss: 0.2009
# Train Epoch: 49 ===> Train set loss: 0.1923
# Train Epoch: 50 ===> Train set loss: 0.2112
# Train Epoch: 51 ===> Train set loss: 0.2078
# Train Epoch: 52 ===> Train set loss: 0.2043
# Train Epoch: 53 ===> Train set loss: 0.2080
# Train Epoch: 54 ===> Train set loss: 0.2141
# Train Epoch: 55 ===> Train set loss: 0.2134
# Train Epoch: 56 ===> Train set loss: 0.2078
# Train Epoch: 57 ===> Train set loss: 0.2073
# Train Epoch: 58 ===> Train set loss: 0.1987
# Train Epoch: 59 ===> Train set loss: 0.2095
# Train Epoch: 60 ===> Train set loss: 0.2053
# Train Epoch: 61 ===> Train set loss: 0.2013
# Train Epoch: 62 ===> Train set loss: 0.2133
# Train Epoch: 63 ===> Train set loss: 0.2081
# Train Epoch: 64 ===> Train set loss: 0.2091
# Train Epoch: 65 ===> Train set loss: 0.2037
# Train Epoch: 66 ===> Train set loss: 0.2077
# Train Epoch: 67 ===> Train set loss: 0.1987
# Train Epoch: 68 ===> Train set loss: 0.2140
# Train Epoch: 69 ===> Train set loss: 0.1996
# Train Epoch: 70 ===> Train set loss: 0.2063
# Train Epoch: 71 ===> Train set loss: 0.2101
# Train Epoch: 72 ===> Train set loss: 0.2050
# Train Epoch: 73 ===> Train set loss: 0.2168
# Train Epoch: 74 ===> Train set loss: 0.2048
# Train Epoch: 75 ===> Train set loss: 0.2062
# Train Epoch: 76 ===> Train set loss: 0.2026
# Train Epoch: 77 ===> Train set loss: 0.2049
# Train Epoch: 78 ===> Train set loss: 0.1996
# Train Epoch: 79 ===> Train set loss: 0.2069
# Train Epoch: 80 ===> Train set loss: 0.2097
# Train Epoch: 81 ===> Train set loss: 0.2146
# Train Epoch: 82 ===> Train set loss: 0.2087
# Train Epoch: 83 ===> Train set loss: 0.2093
# Train Epoch: 84 ===> Train set loss: 0.2089
# Train Epoch: 85 ===> Train set loss: 0.1999
# Train Epoch: 86 ===> Train set loss: 0.2051
# Train Epoch: 87 ===> Train set loss: 0.1988
# Train Epoch: 88 ===> Train set loss: 0.2047
# Train Epoch: 89 ===> Train set loss: 0.1999
# Train Epoch: 90 ===> Train set loss: 0.2059
# Train Epoch: 91 ===> Train set loss: 0.2115
# Train Epoch: 92 ===> Train set loss: 0.2040
# Train Epoch: 93 ===> Train set loss: 0.2093
# Train Epoch: 94 ===> Train set loss: 0.2066
# Train Epoch: 95 ===> Train set loss: 0.2104
# Train Epoch: 96 ===> Train set loss: 0.2038
# Train Epoch: 97 ===> Train set loss: 0.2121
# Train Epoch: 98 ===> Train set loss: 0.2086
# Train Epoch: 99 ===> Train set loss: 0.2084
# Train Epoch: 100 ===> Train set loss: 0.2070
# Train Epoch: 101 ===> Train set loss: 0.2136
# Train Epoch: 102 ===> Train set loss: 0.1989
# Train Epoch: 103 ===> Train set loss: 0.2034
# Train Epoch: 104 ===> Train set loss: 0.2133
# Train Epoch: 105 ===> Train set loss: 0.2046
# Train Epoch: 106 ===> Train set loss: 0.2000
# Train Epoch: 107 ===> Train set loss: 0.2092
# Train Epoch: 108 ===> Train set loss: 0.2040
# Train Epoch: 109 ===> Train set loss: 0.2075
# Train Epoch: 110 ===> Train set loss: 0.2087
# Train Epoch: 111 ===> Train set loss: 0.2022
# Train Epoch: 112 ===> Train set loss: 0.2058
# Train Epoch: 113 ===> Train set loss: 0.2035
# Train Epoch: 114 ===> Train set loss: 0.2008
# Train Epoch: 115 ===> Train set loss: 0.2020
# Train Epoch: 116 ===> Train set loss: 0.2053
# Train Epoch: 117 ===> Train set loss: 0.2040
# Train Epoch: 118 ===> Train set loss: 0.2098
# Train Epoch: 119 ===> Train set loss: 0.2082
# Train Epoch: 120 ===> Train set loss: 0.2082
# Train Epoch: 121 ===> Train set loss: 0.2045
# Train Epoch: 122 ===> Train set loss: 0.2052
# Train Epoch: 123 ===> Train set loss: 0.2049
# Train Epoch: 124 ===> Train set loss: 0.2070
# Train Epoch: 125 ===> Train set loss: 0.1958
# Train Epoch: 126 ===> Train set loss: 0.2067
# Train Epoch: 127 ===> Train set loss: 0.2082
# Train Epoch: 128 ===> Train set loss: 0.2007
# Train Epoch: 129 ===> Train set loss: 0.2088
# Train Epoch: 130 ===> Train set loss: 0.1935
# Train Epoch: 131 ===> Train set loss: 0.2050
# Train Epoch: 132 ===> Train set loss: 0.2043
# Train Epoch: 133 ===> Train set loss: 0.1968
# Train Epoch: 134 ===> Train set loss: 0.1987
# Train Epoch: 135 ===> Train set loss: 0.2061
# Train Epoch: 136 ===> Train set loss: 0.2059
# Train Epoch: 137 ===> Train set loss: 0.2111
# Train Epoch: 138 ===> Train set loss: 0.2011
# Train Epoch: 139 ===> Train set loss: 0.2086
# Train Epoch: 140 ===> Train set loss: 0.2083
# Train Epoch: 141 ===> Train set loss: 0.2010
# Train Epoch: 142 ===> Train set loss: 0.2020
# Train Epoch: 143 ===> Train set loss: 0.2082
# Train Epoch: 144 ===> Train set loss: 0.2137
# Train Epoch: 145 ===> Train set loss: 0.2000
# Train Epoch: 146 ===> Train set loss: 0.2180
# Train Epoch: 147 ===> Train set loss: 0.2063
# Train Epoch: 148 ===> Train set loss: 0.2116
# Train Epoch: 149 ===> Train set loss: 0.2103
# Train Epoch: 150 ===> Train set loss: 0.2113
# Train Epoch: 151 ===> Train set loss: 0.2117
# Train Epoch: 152 ===> Train set loss: 0.2058
# Train Epoch: 153 ===> Train set loss: 0.2164
# Train Epoch: 154 ===> Train set loss: 0.2049
# Train Epoch: 155 ===> Train set loss: 0.2106
# Train Epoch: 156 ===> Train set loss: 0.2037
# Train Epoch: 157 ===> Train set loss: 0.2025
# Train Epoch: 158 ===> Train set loss: 0.2005
# Train Epoch: 159 ===> Train set loss: 0.2113
# Train Epoch: 160 ===> Train set loss: 0.1978
# Train Epoch: 161 ===> Train set loss: 0.2066
# Train Epoch: 162 ===> Train set loss: 0.2021
# Train Epoch: 163 ===> Train set loss: 0.2074
# Train Epoch: 164 ===> Train set loss: 0.2092
# Train Epoch: 165 ===> Train set loss: 0.2022
# Train Epoch: 166 ===> Train set loss: 0.2107
# Train Epoch: 167 ===> Train set loss: 0.2100
# Train Epoch: 168 ===> Train set loss: 0.2022
# Train Epoch: 169 ===> Train set loss: 0.2022
# Train Epoch: 170 ===> Train set loss: 0.2026
# Train Epoch: 171 ===> Train set loss: 0.2106
# Train Epoch: 172 ===> Train set loss: 0.2076
# Train Epoch: 173 ===> Train set loss: 0.2109
# Train Epoch: 174 ===> Train set loss: 0.2085
# Train Epoch: 175 ===> Train set loss: 0.2001
# Train Epoch: 176 ===> Train set loss: 0.2028
# Train Epoch: 177 ===> Train set loss: 0.2035
# Train Epoch: 178 ===> Train set loss: 0.2041
# Train Epoch: 179 ===> Train set loss: 0.2058
# Train Epoch: 180 ===> Train set loss: 0.2135
# Train Epoch: 181 ===> Train set loss: 0.2005
# Train Epoch: 182 ===> Train set loss: 0.2124
# Train Epoch: 183 ===> Train set loss: 0.2136
# Train Epoch: 184 ===> Train set loss: 0.2037
# Train Epoch: 185 ===> Train set loss: 0.2049
# Train Epoch: 186 ===> Train set loss: 0.2057
# Train Epoch: 187 ===> Train set loss: 0.1981
# Train Epoch: 188 ===> Train set loss: 0.2054
# Train Epoch: 189 ===> Train set loss: 0.2024
# Train Epoch: 190 ===> Train set loss: 0.2089
# Train Epoch: 191 ===> Train set loss: 0.2100
# Train Epoch: 192 ===> Train set loss: 0.2022
# Train Epoch: 193 ===> Train set loss: 0.2072
# Train Epoch: 194 ===> Train set loss: 0.2082
# Train Epoch: 195 ===> Train set loss: 0.2147
# Train Epoch: 196 ===> Train set loss: 0.2055
# Train Epoch: 197 ===> Train set loss: 0.1992
# Train Epoch: 198 ===> Train set loss: 0.1953
# Train Epoch: 199 ===> Train set loss: 0.2130
# Train Epoch: 200 ===> Train set loss: 0.2100
# Train Epoch: 201 ===> Train set loss: 0.2034
# Train Epoch: 202 ===> Train set loss: 0.2092
# Train Epoch: 203 ===> Train set loss: 0.2136
# Train Epoch: 204 ===> Train set loss: 0.2094
# Train Epoch: 205 ===> Train set loss: 0.2067
# Train Epoch: 206 ===> Train set loss: 0.2001
# Train Epoch: 207 ===> Train set loss: 0.2049
# Train Epoch: 208 ===> Train set loss: 0.2092
# Train Epoch: 209 ===> Train set loss: 0.2060
# Train Epoch: 210 ===> Train set loss: 0.2113
# Train Epoch: 211 ===> Train set loss: 0.2062
# Train Epoch: 212 ===> Train set loss: 0.2035
# Train Epoch: 213 ===> Train set loss: 0.2128
# Train Epoch: 214 ===> Train set loss: 0.2123
# Train Epoch: 215 ===> Train set loss: 0.2104
# Train Epoch: 216 ===> Train set loss: 0.2048
# Train Epoch: 217 ===> Train set loss: 0.2032
# Train Epoch: 218 ===> Train set loss: 0.2109
# Train Epoch: 219 ===> Train set loss: 0.2098
# Train Epoch: 220 ===> Train set loss: 0.2088
# Train Epoch: 221 ===> Train set loss: 0.2033
# Train Epoch: 222 ===> Train set loss: 0.2082
# Train Epoch: 223 ===> Train set loss: 0.2058
# Train Epoch: 224 ===> Train set loss: 0.2091
# Train Epoch: 225 ===> Train set loss: 0.2048
# Train Epoch: 226 ===> Train set loss: 0.2140
# Train Epoch: 227 ===> Train set loss: 0.2089
# Train Epoch: 228 ===> Train set loss: 0.1988
# Train Epoch: 229 ===> Train set loss: 0.2047
# Train Epoch: 230 ===> Train set loss: 0.2085
# Train Epoch: 231 ===> Train set loss: 0.2130
# Train Epoch: 232 ===> Train set loss: 0.2092
# Train Epoch: 233 ===> Train set loss: 0.2068
# Train Epoch: 234 ===> Train set loss: 0.1964
# Train Epoch: 235 ===> Train set loss: 0.1980
# Train Epoch: 236 ===> Train set loss: 0.2145
# Train Epoch: 237 ===> Train set loss: 0.2147
# Train Epoch: 238 ===> Train set loss: 0.2049
# Train Epoch: 239 ===> Train set loss: 0.2025
# Train Epoch: 240 ===> Train set loss: 0.2093
# Train Epoch: 241 ===> Train set loss: 0.2080
# Train Epoch: 242 ===> Train set loss: 0.2073
# Train Epoch: 243 ===> Train set loss: 0.2085
# Train Epoch: 244 ===> Train set loss: 0.2073
# Train Epoch: 245 ===> Train set loss: 0.2048
# Train Epoch: 246 ===> Train set loss: 0.2050
# Train Epoch: 247 ===> Train set loss: 0.2067
# Train Epoch: 248 ===> Train set loss: 0.2075
# Train Epoch: 249 ===> Train set loss: 0.1962
# Train Epoch: 250 ===> Train set loss: 0.2072
# Train Epoch: 251 ===> Train set loss: 0.2140
# Train Epoch: 252 ===> Train set loss: 0.2109
# Train Epoch: 253 ===> Train set loss: 0.2089
# Train Epoch: 254 ===> Train set loss: 0.2068
# Train Epoch: 255 ===> Train set loss: 0.2122
# Train Epoch: 256 ===> Train set loss: 0.2097
# Train Epoch: 257 ===> Train set loss: 0.2043
# Train Epoch: 258 ===> Train set loss: 0.2038
# Train Epoch: 259 ===> Train set loss: 0.2103
# Train Epoch: 260 ===> Train set loss: 0.2187
# Train Epoch: 261 ===> Train set loss: 0.2070
# Train Epoch: 262 ===> Train set loss: 0.2015
# Train Epoch: 263 ===> Train set loss: 0.2135
# Train Epoch: 264 ===> Train set loss: 0.2085
# Train Epoch: 265 ===> Train set loss: 0.2084
# Train Epoch: 266 ===> Train set loss: 0.2055
# Train Epoch: 267 ===> Train set loss: 0.2002
# Train Epoch: 268 ===> Train set loss: 0.2171
# Train Epoch: 269 ===> Train set loss: 0.2131
# Train Epoch: 270 ===> Train set loss: 0.2042
# Train Epoch: 271 ===> Train set loss: 0.1988
# Train Epoch: 272 ===> Train set loss: 0.2189
# Train Epoch: 273 ===> Train set loss: 0.2079
# Train Epoch: 274 ===> Train set loss: 0.2108
# Train Epoch: 275 ===> Train set loss: 0.2067
# Train Epoch: 276 ===> Train set loss: 0.1965
# Train Epoch: 277 ===> Train set loss: 0.1972
# Train Epoch: 278 ===> Train set loss: 0.2006
# Train Epoch: 279 ===> Train set loss: 0.2117
# Train Epoch: 280 ===> Train set loss: 0.2102
# Train Epoch: 281 ===> Train set loss: 0.2072
# Train Epoch: 282 ===> Train set loss: 0.2052
# Train Epoch: 283 ===> Train set loss: 0.2001
# Train Epoch: 284 ===> Train set loss: 0.2084
# Train Epoch: 285 ===> Train set loss: 0.2072
# Train Epoch: 286 ===> Train set loss: 0.2042
# Train Epoch: 287 ===> Train set loss: 0.2080
# Train Epoch: 288 ===> Train set loss: 0.2053
# Train Epoch: 289 ===> Train set loss: 0.2057
# Train Epoch: 290 ===> Train set loss: 0.2102
# Train Epoch: 291 ===> Train set loss: 0.2071
# Train Epoch: 292 ===> Train set loss: 0.2067
# Train Epoch: 293 ===> Train set loss: 0.2057
# Train Epoch: 294 ===> Train set loss: 0.1987
# Train Epoch: 295 ===> Train set loss: 0.2036
# Train Epoch: 296 ===> Train set loss: 0.2034
# Train Epoch: 297 ===> Train set loss: 0.2089
# Train Epoch: 298 ===> Train set loss: 0.2157
# Train Epoch: 299 ===> Train set loss: 0.1965
# Train Epoch: 300 ===> Train set loss: 0.2067
# Train Epoch: 301 ===> Train set loss: 0.2051
# Train Epoch: 302 ===> Train set loss: 0.2099
# Train Epoch: 303 ===> Train set loss: 0.2104
# Train Epoch: 304 ===> Train set loss: 0.2078
# Train Epoch: 305 ===> Train set loss: 0.2046
# Train Epoch: 306 ===> Train set loss: 0.2090
# Train Epoch: 307 ===> Train set loss: 0.2093
# Train Epoch: 308 ===> Train set loss: 0.2040
# Train Epoch: 309 ===> Train set loss: 0.2065
# Train Epoch: 310 ===> Train set loss: 0.2143
# Train Epoch: 311 ===> Train set loss: 0.2084
# Train Epoch: 312 ===> Train set loss: 0.2108
# Train Epoch: 313 ===> Train set loss: 0.2064
# Train Epoch: 314 ===> Train set loss: 0.2065
# Train Epoch: 315 ===> Train set loss: 0.2099
# Train Epoch: 316 ===> Train set loss: 0.2065
# Train Epoch: 317 ===> Train set loss: 0.2021
# Train Epoch: 318 ===> Train set loss: 0.2060
# Train Epoch: 319 ===> Train set loss: 0.2119
# Train Epoch: 320 ===> Train set loss: 0.2053
# Train Epoch: 321 ===> Train set loss: 0.2103
# Train Epoch: 322 ===> Train set loss: 0.2059
# Train Epoch: 323 ===> Train set loss: 0.2082
# Train Epoch: 324 ===> Train set loss: 0.2116
# Train Epoch: 325 ===> Train set loss: 0.2045
# Train Epoch: 326 ===> Train set loss: 0.2113
# Train Epoch: 327 ===> Train set loss: 0.2063
# Train Epoch: 328 ===> Train set loss: 0.2036
# Train Epoch: 329 ===> Train set loss: 0.2058
# Train Epoch: 330 ===> Train set loss: 0.2089
# Train Epoch: 331 ===> Train set loss: 0.2034
# Train Epoch: 332 ===> Train set loss: 0.2057
# Train Epoch: 333 ===> Train set loss: 0.2051
# Train Epoch: 334 ===> Train set loss: 0.2080
# Train Epoch: 335 ===> Train set loss: 0.2065
# Train Epoch: 336 ===> Train set loss: 0.2131
# Train Epoch: 337 ===> Train set loss: 0.2048
# Train Epoch: 338 ===> Train set loss: 0.2102
# Train Epoch: 339 ===> Train set loss: 0.2095
# Train Epoch: 340 ===> Train set loss: 0.2034
# Train Epoch: 341 ===> Train set loss: 0.2014
# Train Epoch: 342 ===> Train set loss: 0.2113
# Train Epoch: 343 ===> Train set loss: 0.2025
# Train Epoch: 344 ===> Train set loss: 0.2016
# Train Epoch: 345 ===> Train set loss: 0.2118
# Train Epoch: 346 ===> Train set loss: 0.1964
# Train Epoch: 347 ===> Train set loss: 0.2069
# Train Epoch: 348 ===> Train set loss: 0.2053
# Train Epoch: 349 ===> Train set loss: 0.2012
# Train Epoch: 350 ===> Train set loss: 0.2118
# Train Epoch: 351 ===> Train set loss: 0.2069
# Train Epoch: 352 ===> Train set loss: 0.2048
# Train Epoch: 353 ===> Train set loss: 0.2023
# Train Epoch: 354 ===> Train set loss: 0.2122
# Train Epoch: 355 ===> Train set loss: 0.2138
# Train Epoch: 356 ===> Train set loss: 0.2038
# Train Epoch: 357 ===> Train set loss: 0.2124
# Train Epoch: 358 ===> Train set loss: 0.1966
# Train Epoch: 359 ===> Train set loss: 0.2020
# Train Epoch: 360 ===> Train set loss: 0.2077
# Train Epoch: 361 ===> Train set loss: 0.1963
# Train Epoch: 362 ===> Train set loss: 0.2088
# Train Epoch: 363 ===> Train set loss: 0.2048
# Train Epoch: 364 ===> Train set loss: 0.2038
# Train Epoch: 365 ===> Train set loss: 0.2077
# Train Epoch: 366 ===> Train set loss: 0.2031
# Train Epoch: 367 ===> Train set loss: 0.2077
# Train Epoch: 368 ===> Train set loss: 0.2043
# Train Epoch: 369 ===> Train set loss: 0.1965
# Train Epoch: 370 ===> Train set loss: 0.2019
# Train Epoch: 371 ===> Train set loss: 0.2056
# Train Epoch: 372 ===> Train set loss: 0.2123
# Train Epoch: 373 ===> Train set loss: 0.2218
# Train Epoch: 374 ===> Train set loss: 0.2051
# Train Epoch: 375 ===> Train set loss: 0.2057
# Train Epoch: 376 ===> Train set loss: 0.2006
# Train Epoch: 377 ===> Train set loss: 0.2113
# Train Epoch: 378 ===> Train set loss: 0.2064
# Train Epoch: 379 ===> Train set loss: 0.2044
# Train Epoch: 380 ===> Train set loss: 0.2078
# Train Epoch: 381 ===> Train set loss: 0.2104
# Train Epoch: 382 ===> Train set loss: 0.2118
# Train Epoch: 383 ===> Train set loss: 0.2118
# Train Epoch: 384 ===> Train set loss: 0.1994
# Train Epoch: 385 ===> Train set loss: 0.2078
# Train Epoch: 386 ===> Train set loss: 0.2026
# Train Epoch: 387 ===> Train set loss: 0.2017
# Train Epoch: 388 ===> Train set loss: 0.2011
# Train Epoch: 389 ===> Train set loss: 0.2092
# Train Epoch: 390 ===> Train set loss: 0.2095
# Train Epoch: 391 ===> Train set loss: 0.2006
# Train Epoch: 392 ===> Train set loss: 0.2070
# Train Epoch: 393 ===> Train set loss: 0.2084
# Train Epoch: 394 ===> Train set loss: 0.2070

# %%
R = R_net(X0).detach().numpy()
y0 = Y0.detach().numpy()
print(np.shape(y0))
print(np.shape(R))
# Out:
# (20000, 2)
# (20000, 2)

# %%
# R = R_net(X0.to(device))
# plt.plot(X0_bar.cpu().detach().numpy()[:, 0], R.cpu().detach().numpy()[:, 0], 'o')

fig, ax = plt.subplots(figsize=(8, 5))
Rd1 = ax.scatter(y0[:,0], y0[:,1], marker='o',lw = 0.5, c = R[:,0], cmap = plt.cm.get_cmap('nipy_spectral', 20))
ax.set_title('R(X)_dim1')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
fig.colorbar(Rd1)

# %%
# R = R_net(X0.to(device))
# plt.plot(X0_bar.cpu().detach().numpy()[:, 0], R.cpu().detach().numpy()[:, 0], 'o')

fig, ax = plt.subplots(figsize=(8, 5))
Rd2 = ax.scatter(y0[:,0], y0[:,1], marker='o',lw = 0.5, c = R[:,1], cmap = plt.cm.get_cmap('nipy_spectral', 20))
ax.set_title('R(X)_dim2')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
fig.colorbar(Rd2)
